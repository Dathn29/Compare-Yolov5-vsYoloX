# %%
# !git clone https://github.com/Megvii-BaseDetection/YOLOX.git

# %%
# %cd #yoloX path
# Out:
# /content/drive/MyDrive/Coco/yoloX/YOLOX

# %%
# !pip install -r requirements.txt

# %%
# !python3 export_onnx.py --output-name yolox_s.onnx -n yolox-s -c #path yolox.pth

# %%
# %cd /content/drive/MyDrive/Coco/yoloX/YOLOX
# Out:
# /content/drive/MyDrive/Coco/yoloX/YOLOX

# %%
# !python3 onnx_inference.py -m <path yolox.onnx> -i <path img> -o <save_dir> -s 0.3 --input_shape 640,640
# Out:
# output name output
# output shape [1, 8400, 85]
# output type tensor(float)
